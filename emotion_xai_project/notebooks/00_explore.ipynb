# %%
import pandas as pd
import os
from pathlib import Path

base = Path("..") / "data" / "raw"

# FER2013
fer_train = base / "fer2013" / "train"
print("✅ FER images:", sum(len(files) for _, _, files in os.walk(fer_train)))

# ASSISTments
print(
    "✅ ASSIST rows:",
    pd.read_csv(base / "ASSISTments_Data_Set_2012-2013.csv", nrows=1).shape
)

# Dyslexia (desktop version)
print(
    "✅ Dyslexia rows:",
    pd.read_csv(
        base / "Predicting Risk of Dyslexia - PLOS ONE" / "Dyt-desktop.csv"
    ).shape
)

print("🎉 READY FOR MODELING!")
# Out:
# ✅ FER images: 28710
# ✅ ASSIST rows: (1, 35)
# ✅ Dyslexia rows: (3644, 1)
# 🎉 READY FOR MODELING!
